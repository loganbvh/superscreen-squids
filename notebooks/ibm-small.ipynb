# %%
# %config InlineBackend.figure_formats = {"retina", "png"}
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import superscreen as sc
from superscreen.geometry import box

import sys
sys.path.insert(0, "..")
import squids

# %%
squid = squids.ibm.small.make_squid()

# %%
fig, ax = squid.draw()

# %%
squid.make_mesh(max_edge_length=0.1, smooth=100)

# %%
squid.mesh_stats()
# Out:
# <table><tr><h2>Mesh Statistics</h2></tr><tr><td></td><td><b>length_units</b></td><td>'um'</td></tr><tr><td><b>'fc'</b></td><td><b>num_sites</b></td><td>1993</td></tr><tr><td></td><td><b>num_elements</b></td><td>3484</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>1.663e-02</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>9.726e-02</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>1.041e-04</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>6.870e-03</td></tr><tr><td><b>'fc_shield'</b></td><td><b>num_sites</b></td><td>2313</td></tr><tr><td></td><td><b>num_elements</b></td><td>4391</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>1.563e-02</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>1.022e-01</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>2.037e-04</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>5.936e-03</td></tr><tr><td><b>'pl_shield1'</b></td><td><b>num_sites</b></td><td>2332</td></tr><tr><td></td><td><b>num_elements</b></td><td>4426</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>1.368e-02</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>9.197e-02</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>1.993e-04</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>6.272e-03</td></tr><tr><td><b>'pl_shield2'</b></td><td><b>num_sites</b></td><td>1669</td></tr><tr><td></td><td><b>num_elements</b></td><td>3120</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>1.279e-02</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>1.008e-01</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>1.078e-04</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>6.741e-03</td></tr><tr><td><b>'pl'</b></td><td><b>num_sites</b></td><td>2261</td></tr><tr><td></td><td><b>num_elements</b></td><td>4313</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>1.821e-02</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>9.429e-02</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>3.688e-04</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>6.767e-03</td></tr></table>

# %%
fig, ax = squid.plot_mesh()
_ = squid.plot_polygons(ax=ax, color="k")

# %%
I_fc = "1 mA"

solutions = sc.solve(
    squid,
    terminal_currents={"fc": {"source": I_fc, "drain": f"-{I_fc}"}},
    iterations=10,
)
# Out:
# Layer 'fc': The film thickness, d = 0.1600 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0400 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.
# Layer 'fc_shield': The film thickness, d = 0.1000 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0640 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.
# Layer 'pl_shield1': The film thickness, d = 0.2000 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0320 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.
# Layer 'pl_shield2': The film thickness, d = 0.1600 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0400 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.
# Layer 'pl': The film thickness, d = 0.1000 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0640 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.

# %%
fig, axes = solutions[-1].plot_fields(films=["pl", "pl_shield1", "fc_shield"], figsize=(8, 2.5))
fig.tight_layout()

# %%
fig, axes = solutions[-1].plot_currents(max_cols=2, figsize=(8, 8))
fig.tight_layout()

# %%
eval_mesh = sc.Polygon(points=box(5, 5, points=401)).make_mesh(max_edge_length=0.1)

# %%
_ = solutions[-1].plot_field_at_positions(eval_mesh, zs=0)

# %%
fluxoids = [sum(solution.hole_fluxoid("pl_center")) for solution in solutions]
mutual_inductance = [(fluxoid / sc.ureg(I_fc)).to("Phi_0 / A").m for fluxoid in fluxoids]

# %%
print(f"Mutual inductance = {mutual_inductance[-1]:.1f} Phi_0 / A")

fig, (ax, bx) = plt.subplots(1, 2, sharex=True, figsize=(6, 3), constrained_layout=True)
ax.plot(range(len(mutual_inductance)), mutual_inductance, "o--")
ax.grid(True)
ax.set_title("Mutual inductance value")
ax.set_xlabel("Solver iteration")
ax.set_ylabel("Mutual inductance [$\\Phi_0$ / A]")

diff = np.diff(mutual_inductance)
bx.plot(range(1, len(mutual_inductance)), np.abs(diff / mutual_inductance[1:]), ".-")
bx.set_yscale("log")
bx.grid(True)
bx.set_title("Mutual inductance convergence")
bx.set_xlabel("Solver iteration")
_ = bx.set_ylabel("Fractional change\nin mutual inductance")
# Out:
# Mutual inductance = 72.8 Phi_0 / A

# %%
sc.version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>SuperScreen</td><td>0.9.0</td></tr><tr><td>Numpy</td><td>1.23.3</td></tr><tr><td>Numba</td><td>0.57.0</td></tr><tr><td>SciPy</td><td>1.9.1</td></tr><tr><td>matplotlib</td><td>3.6.0</td></tr><tr><td>IPython</td><td>8.5.0</td></tr><tr><td>Python</td><td>3.9.13 | packaged by conda-forge | (main, May 27 2022, 17:01:00)
# [Clang 13.0.1 ]</td></tr><tr><td>OS</td><td>posix [darwin]</td></tr><tr><td>Number of CPUs</td><td>Physical: 10, Logical: 10</td></tr><tr><td>BLAS Info</td><td>OPENBLAS</td></tr><tr><td colspan='2'>Sun May 14 18:16:43 2023 PDT</td></tr></table>
