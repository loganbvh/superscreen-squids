# %%
# %config InlineBackend.figure_formats = {"retina", "png"}
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import superscreen as sc
from superscreen.geometry import box

import sys
sys.path.insert(0, "..")
import squids

# %%
squid = squids.huber.make_squid()

# %%
fig, ax = squid.draw()

# %%
squid.make_mesh(max_edge_length=0.4, smooth=100)

# %%
squid.mesh_stats()
# Out:
# <table><tr><h2>Mesh Statistics</h2></tr><tr><td></td><td><b>length_units</b></td><td>'um'</td></tr><tr><td><b>'fc'</b></td><td><b>num_sites</b></td><td>4385</td></tr><tr><td></td><td><b>num_elements</b></td><td>7768</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>6.348e-02</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>4.022e-01</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>2.082e-03</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>1.145e-01</td></tr><tr><td><b>'fc_shield'</b></td><td><b>num_sites</b></td><td>2130</td></tr><tr><td></td><td><b>num_elements</b></td><td>4105</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>1.213e-01</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>4.002e-01</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>8.028e-03</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>1.288e-01</td></tr><tr><td><b>'pl'</b></td><td><b>num_sites</b></td><td>1573</td></tr><tr><td></td><td><b>num_elements</b></td><td>2994</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>1.302e-01</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>3.947e-01</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>1.835e-02</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>1.157e-01</td></tr><tr><td><b>'pl_shield'</b></td><td><b>num_sites</b></td><td>1153</td></tr><tr><td></td><td><b>num_elements</b></td><td>2154</td></tr><tr><td></td><td><b>min_edge_length</b></td><td>1.195e-01</td></tr><tr><td></td><td><b>max_edge_length</b></td><td>4.069e-01</td></tr><tr><td></td><td><b>min_vertex_area</b></td><td>8.258e-03</td></tr><tr><td></td><td><b>max_vertex_area</b></td><td>1.120e-01</td></tr></table>

# %%
fig, ax = squid.plot_mesh()
_ = squid.plot_polygons(ax=ax, color="k")

# %%
I_fc = "1 mA"

solutions = sc.solve(
    squid,
    terminal_currents={"fc": {"source": I_fc, "drain": f"-{I_fc}"}},
    iterations=10,
)
# Out:
# Layer 'fc': The film thickness, d = 0.2000 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0320 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.
# Layer 'fc_shield': The film thickness, d = 0.2300 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0278 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.
# Layer 'pl': The film thickness, d = 0.2300 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0278 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.
# Layer 'pl_shield': The film thickness, d = 0.2500 µm, is greater than or equal to the London penetration depth, resulting in an effective penetration depth Λ = 0.0256 µm <= λ = 0.0800 µm. The assumption that the current density is nearly constant over the thickness of the film may not be valid.

# %%
fig, axes = solutions[-1].plot_fields(films=["pl", "pl_shield", "fc_shield"], figsize=(8, 2.5))
fig.tight_layout()

# %%
fig, axes = solutions[-1].plot_currents(max_cols=2, figsize=(8, 8))
fig.tight_layout()

# %%
eval_mesh = sc.Polygon(points=box(20, 20, points=401)).make_mesh(max_edge_length=0.5)

# %%
_ = solutions[-1].plot_field_at_positions(eval_mesh, zs=-0.5)

# %%
fluxoids = [sum(solution.hole_fluxoid("pl_center")) for solution in solutions]
mutual_inductance = [(fluxoid / sc.ureg(I_fc)).to("Phi_0 / A").m for fluxoid in fluxoids]

# %%
print(f"Mutual inductance = {mutual_inductance[-1]:.1f} Phi_0 / A")

fig, (ax, bx) = plt.subplots(1, 2, sharex=True, figsize=(6, 3), constrained_layout=True)
ax.plot(range(len(mutual_inductance)), mutual_inductance, "o--")
ax.grid(True)
ax.set_title("Mutual inductance value")
ax.set_xlabel("Solver iteration")
ax.set_ylabel("Mutual inductance [$\\Phi_0$ / A]")

diff = np.diff(mutual_inductance)
bx.plot(range(1, len(mutual_inductance)), np.abs(diff / mutual_inductance[1:]), ".-")
bx.set_yscale("log")
bx.grid(True)
bx.set_title("Mutual inductance convergence")
bx.set_xlabel("Solver iteration")
_ = bx.set_ylabel("Fractional change\nin mutual inductance")
# Out:
# Mutual inductance = 882.0 Phi_0 / A

# %%
sc.version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>SuperScreen</td><td>0.9.0</td></tr><tr><td>Numpy</td><td>1.23.3</td></tr><tr><td>Numba</td><td>0.57.0</td></tr><tr><td>SciPy</td><td>1.9.1</td></tr><tr><td>matplotlib</td><td>3.6.0</td></tr><tr><td>IPython</td><td>8.5.0</td></tr><tr><td>Python</td><td>3.9.13 | packaged by conda-forge | (main, May 27 2022, 17:01:00)
# [Clang 13.0.1 ]</td></tr><tr><td>OS</td><td>posix [darwin]</td></tr><tr><td>Number of CPUs</td><td>Physical: 10, Logical: 10</td></tr><tr><td>BLAS Info</td><td>OPENBLAS</td></tr><tr><td colspan='2'>Sun May 14 18:02:29 2023 PDT</td></tr></table>
